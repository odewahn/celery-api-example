# %% [markdown]
# First we need to load the data

# %%
# !wget --no-check-certificate  https://admin.sfo.safariflow.com:5555/flower/api/workers
# Out:
# --2018-03-05 11:46:45--  https://admin.sfo.safariflow.com:5555/flower/api/workers
# Resolving admin.sfo.safariflow.com (admin.sfo.safariflow.com)... 10.16.32.22
# Connecting to admin.sfo.safariflow.com (admin.sfo.safariflow.com)|10.16.32.22|:5555... connected.
# WARNING: cannot verify admin.sfo.safariflow.com's certificate, issued by ‘emailAddress=infrastructure@safaribooksonline.com,CN=Safari Books Online Intermediate CA,OU=Infrastructure,O=Safari Books Online,ST=California,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/json]
# Saving to: ‘workers.4’
#
# workers.4               [     <=>            ] 536.65K   479KB/s    in 1.1s
#
# 2018-03-05 11:46:47 (479 KB/s) - ‘workers.4’ saved [2189549]

# %%
import json

# %%
# reading the JSON data using json.load()
file = 'workers.3'
with open(file) as train_file:
    workers = json.load(train_file)

# %%
from collections import defaultdict

summary = defaultdict(int)
for worker in workers.keys():
   if "stats" in workers[worker].keys():
    for task in workers[worker]["stats"]['total'].keys():
        summary[task] += workers[worker]["stats"]['total'][task]

# %%
import pandas as pd

# %%
df = pd.DataFrame(sorted(summary.iteritems(), key=lambda (k,v): v, reverse=True), columns=["Job", "Complted tasks"])

# %%
df
# Out:
#                                                   Job  Complted tasks
# 0   heron.tasks.create_heron_progress_from_coot_usage         3624393
# 1               feather.messaging.rabbit_send_message          241080
# 2   live_training.tasks.process_refreshed_course_d...          190311
# 3                       cacheback.tasks.refresh_cache           63249
# 4               nest.reader_api.tasks.SaveUsageEvents           40020
# 5   feather.messaging.rabbit_refresh_and_send_mode...           31174
# 6                  subscribe.tasks.check_subscription            9986
# 7                         update_user_activity_metric            9564
# 8             salesforce.tasks.create_salesforce_user            4243
# 9                          heron.tasks.ping_feed_hubs            2461
# 10                  heron.tasks.sync_with_exacttarget            2287
# 11  live_training.tasks.sync_individual_course_dat...            1741
# 12     heron.tasks.synchronize_exacttarget_subscriber            1096
# 13       live_training.tasks.sync_association_to_upas             561
# 14  live_training.tasks.add_to_exacttarget_registe...             467
# 15                   heron.tasks.send_triggered_email             401
# 16      customeradmin.tasks.add_users_to_team_account             161
# 17  salesforce.tasks.update_or_create_salesforce_c...             142
# 18    heron.exacttarget.send_anon_user_register_email              96
# 19                 heron.tasks.fire_exacttarget_event              66
# 20             subscribe.tasks.refresh_account_status              62
# 21  live_training.tasks.remove_from_exacttarget_re...              58
# 22  conferences.tasks.add_exacttarget_conference_c...              45
# 23                subscribe.tasks.update_zuora_crm_id              40
# 24                  heron.tasks.newrelic_custom_event              37
# 25  live_training.tasks.add_to_exacttarget_waiting...              21
# 26              usage_log.tasks.truncate_usage_events              11
# 27  customeradmin.tasks.spawn_update_cached_user_a...              10
# 28  heron.exacttarget.send_welcome_with_activation...              10
# 29    live_training.tasks.create_live_training_survey               9
# 30                       salesforce.tasks.update_user               6
# 31     conferences.tasks.provision_conference_benefit               6
# 32  live_training.tasks.preregister_live_training_...               6
# 33                        heron.tasks.async_send_mail               5
# 34  customeradmin.tasks.purchase_seats_for_team_ac...               3
# 35   heron.exacttarget.send_b2b_payment_invoice_email               3
# 36  customeradmin.tasks.spawn_update_cached_user_a...               3
# 37  live_training.tasks.remove_from_exacttarget_wa...               3
# 38  salesforce.tasks.create_closed_self_service_op...               3
# 39  salesforce.tasks.create_closed_self_service_op...               2
# 40       salesforce.tasks.create_self_service_account               2
# 41   subscribe.tasks.update_zuora_contact_information               2
# 42                   heron.tasks.render_video_sitemap               1
# 43                 heron.tasks.render_primary_sitemap               1
# 44                    heron.tasks.render_book_sitemap               1
# 45          salesforce.tasks.provision_b2c_subscriber               1
